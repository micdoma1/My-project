# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

print("ready")
# Out:
# ready

# %% [markdown]
# To read csv files:

# %%
df = pd.read_csv ('./dataset/africa_food_prices.csv')

# %% [markdown]
# Analization of the data

# %%
df.shape
# Out:
# (956779, 19)

# %%
df.head()
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers  \
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
# 4       15431         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type
# 0          52  Rice - Retail          0.0      DZD     15      Retail  \
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
# 3          52  Rice - Retail          0.0      DZD     15      Retail
# 4          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price  mp_commoditysource
# ...

# %%
df.head(6)
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers  \
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
# 4       15431         4.0  Algeria       344  Alger       1794  Algiers
# 5       15432         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type
# 0          52  Rice - Retail          0.0      DZD     15      Retail  \
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
# 3          52  Rice - Retail          0.0      DZD     15      Retail
# 4          52  Rice - Retail          0.0      DZD     15      Retail
# ...

# %%
df.tail(6)
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id
# 956773     2050632       271.0  Zimbabwe      3444  Midlands       5594  \
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency
# 956773  Mbilashaba         185            Salt - Retail          0.0      ZWL  \
# 956774  Mbilashaba         432   Beans (sugar) - Retail          0.0      ZWL
# 956775  Mbilashaba         539      Toothpaste - Retail          0.0      ZWL
# 956776  Mbilashaba         540    Laundry soap - Retail          0.0      ZWL
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country_id', 'country', 'state_id', 'state', 'market_id',
#        'market', 'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
#        'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price',
#        'mp_commoditysource'],
#       dtype='object')

# %%
print(df['currency'].unique())
# Out:
# ['DZD' 'AOA' 'XOF' 'BIF' 'XAF' 'CVE' 'DJF' 'EGP' 'ERN' 'ETB' 'GMD' 'GHS'
#  'GNF' 'KES' 'LSL' 'LRD' 'LYD' 'MGA' 'MWK' 'MRO' 'MZN' 'NAD' 'NGN' 'RWF'
#  'SLL' 'SOS' 'ZAR' 'SSP' 'SDG' 'SZL' 'UGX' 'ZMW' 'USD' 'ZWL']

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# country_id                 0
# country                    0
# state_id                   0
# state                 126678
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    956779
# dtype: int64

# %%
# Replace NaN with not specified

df.fillna({"mp_commoditysource": "No Value", "state": "Not Specified"}, inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0            0
# country_id            0
# country               0
# state_id              0
# state                 0
# market_id             0
# market                0
# produce_id            0
# produce               0
# currency_id           0
# currency              0
# pt_id                 0
# market_type           0
# um_unit_id            0
# quantity              0
# month                 0
# year                  0
# price                 0
# mp_commoditysource    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 956774    False
# 956775    False
# 956776    False
# 956777    False
# 956778    False
# Length: 956779, dtype: bool

# %%
# Summary Statistic

df.describe()
# Out:
#          Unnamed: 0     country_id       state_id      market_id
# count  9.567790e+05  956779.000000  956779.000000  956779.000000  \
# mean   1.076345e+06    1961.192782   22287.911831    1392.594222
# std    5.159597e+05   10404.034921   98565.608270    1027.751212
# min    1.542700e+04       4.000000       0.000000     101.000000
# 25%    5.939185e+05      90.000000    1836.000000     528.000000
# 50%    1.113054e+06     155.000000    2209.000000    1078.000000
# 75%    1.513290e+06     205.000000   21971.000000    2281.000000
# max    2.050637e+06   70001.000000  900003.000000    6081.000000
#
#           produce_id  currency_id          pt_id     um_unit_id
# count  956779.000000     956779.0  956779.000000  956779.000000  \
# mean      186.141214          0.0      14.926716      14.017183
# std       165.401303          0.0       0.263570      24.437728
# min        50.000000          0.0      14.000000       5.000000
# ...

# %%
# Grouping data by countries

grp1 = df.copy()
grp1.head
# Out:
# <bound method NDFrame.head of         Unnamed: 0  country_id   country  state_id     state  market_id
# 0            15427         4.0   Algeria       344     Alger       1794  \
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
# ...

# %%
grp1.country.value_counts()
# Out:
# country
# Rwanda                      137746
# Mali                         73843
# Burundi                      60921
# Gambia                       56971
# Niger                        54974
# Nigeria                      50285
# Zambia                       42793
# Mozambique                   42278
# Libya                        41207
# Benin                        39530
# Senegal                      33563
# Ghana                        25414
# Ethiopia                     24627
# Malawi                       22682
# Cameroon                     22476
# Guinea-Bissau                19796
# Chad                         18896
# Somalia                      18444
# South Sudan                  17746
# Central African Republic     12720
# Liberia                      12302
# Guinea                       11810
# Sierra Leone                 11645
# Zimbabwe                     10957
# Mauritania                   10871
# Sudan                         9890
# ...

# %%
# Total number of countries

x = grp1["country"].nunique()
print("There are", x, "number of countries")
# Out:
# There are 42 number of countries

# %%
food_prices = grp1[["country", "state", "produce", "year", "price"]]
food_prices
# Out:
#          country     state                  produce  year      price
# 0        Algeria     Alger            Rice - Retail  2015    90.0000
# 1        Algeria     Alger            Rice - Retail  2015    96.0000
# 2        Algeria     Alger            Rice - Retail  2015    96.0000
# 3        Algeria     Alger            Rice - Retail  2015    83.0000
# 4        Algeria     Alger            Rice - Retail  2015    80.0000
# ...          ...       ...                      ...   ...        ...
# 956774  Zimbabwe  Midlands   Beans (sugar) - Retail  2021   233.3333
# 956775  Zimbabwe  Midlands      Toothpaste - Retail  2021   112.5000
# 956776  Zimbabwe  Midlands    Laundry soap - Retail  2021   114.0000
# 956777  Zimbabwe  Midlands   Handwash soap - Retail  2021    59.5000
# 956778  Zimbabwe  Midlands  Fish (kapenta) - Retail  2021  1200.0000
#
# [956779 rows x 5 columns]

# %%
# Total produce in Nigeria

nigeria = food_prices[food_prices["country"]=="Nigeria"]
nigeria.nunique()
# Out:
# country        1
# state         14
# produce       58
# year          20
# price      13311
# dtype: int64

# %%
stuff = food_prices[(food_prices["country"] == "Nigeria") & (food_prices["produce"] == "Bread - Retail")]
stuff.sort_values("year", ascending=False)
# Out:
#         country    state         produce  year     price
# 653965  Nigeria  Zamfara  Bread - Retail  2021  526.3150
# 632348  Nigeria    Lagos  Bread - Retail  2021  300.0000
# 635711  Nigeria     Yobe  Bread - Retail  2021  139.0000
# 635712  Nigeria     Yobe  Bread - Retail  2021  160.0000
# 635713  Nigeria     Yobe  Bread - Retail  2021  176.5000
# ...         ...      ...             ...   ...       ...
# 630599  Nigeria    Kebbi  Bread - Retail  2014  197.7725
# 630598  Nigeria    Kebbi  Bread - Retail  2014  195.5500
# 633834  Nigeria      Oyo  Bread - Retail  2014  150.0000
# 633835  Nigeria      Oyo  Bread - Retail  2014  250.0000
# 630601  Nigeria    Kebbi  Bread - Retail  2014  195.5525
#
# [1152 rows x 5 columns]

# %%
Yam = food_prices[(food_prices["country"] == "Nigeria") & (food_prices["produce"] == "Yam - Retail")]
Yam.sort_values("year", ascending=False)
# Out:
#         country    state       produce  year    price
# 654550  Nigeria  Zamfara  Yam - Retail  2021  203.087
# 629657  Nigeria  Katsina  Yam - Retail  2021  193.133
# 629659  Nigeria  Katsina  Yam - Retail  2021  193.633
# 610954  Nigeria    Borno  Yam - Retail  2021  574.000
# 610955  Nigeria    Borno  Yam - Retail  2021  585.000
# ...         ...      ...           ...   ...      ...
# 625050  Nigeria   Kaduna  Yam - Retail  2014  101.582
# 625048  Nigeria   Kaduna  Yam - Retail  2014   55.500
# 625052  Nigeria   Kaduna  Yam - Retail  2014   64.578
# 625051  Nigeria   Kaduna  Yam - Retail  2014   66.245
# 621976  Nigeria   Jigawa  Yam - Retail  2014  115.350
#
# [1762 rows x 5 columns]

# %% [markdown]
# Visualization of data

# %%
Yam.plot(kind = "line", x = "state", y = "price", c="orange")
plt.title("Yam Retail Prices in Nigeria")
plt.show()

# %%
sns.barplot(data=stuff, x=stuff.state, y=stuff.price)
# Out:
# <Axes: xlabel='state', ylabel='price'>

# %%
sns.displot(data=stuff, x=stuff.year, y=stuff.price,)
